# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
img = mpimg.imread("test_data/screws_375.png")
img_hsv = plt.colors.rgb_to_hsv(img)

# %%
img_plot= plt.imshow(img)
plt.imshow(img_hsv)

# %%
green_img = img [:, :, 1]*255
plt.imshow(green_img)
print(green_img)
# Out:
# [[150. 155. 160. ...  95.  94.  94.]
#  [151. 156. 155. ...  95.  97.  97.]
#  [158. 161. 161. ...  97.  98.  98.]
#  ...
#  [169. 176. 180. ... 172. 174. 174.]
#  [170. 175. 179. ... 167. 170. 170.]
#  [170. 175. 179. ... 167. 170. 170.]]

# %%
hist,bins = np.histogram(green_img.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(green_img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
