# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt   #We use matplotlib library for plotting
import matplotlib.image as mpimg  
import matplotlib.colors as clr
import numpy as np

# %%
img = mpimg.imread("test_data/screws_375.png")

# %%
img_plot= plt.imshow(img)
plt.colorbar()

# %%
blue_img = img [:, :, 2] * 255
plt.imshow(blue_img)
plt.colorbar()

# %%
hist,bins = np.histogram(blue_img.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(blue_img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
imgplot = plt.imshow(blue_img)
imgplot.set_clim(200, 250)  
'''using blue channel of an image and its corresponding histogram graph we can get meaningful results..'''
# Out:
# 'using blue channel of an image and its corresponding histogram graph we can get meaningful results..'
